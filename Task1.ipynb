# %% [markdown]
# # Wifi Location with Python

# %%
import os
import gc
import pandas as pd
import numpy as np # fundamental package for scientific computing with Python
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
print(os.listdir("./input"))

wifi_train_df = pd.read_csv('./input/trainingData.csv')
# Out:
# ['trainingData.csv', 'validationData.csv']

# %%
print('Size of Wifi train data', wifi_train_df.shape)
# Out:
# Size of Wifi train data (19937, 529)

# %%
wifi_train_df.describe()
# Out:
#              WAP001        WAP002   WAP003   WAP004        WAP005  \
# count  19937.000000  19937.000000  19937.0  19937.0  19937.000000
# mean      99.823644     99.820936    100.0    100.0     99.613733
# std        5.866842      5.798156      0.0      0.0      8.615657
# min      -97.000000    -90.000000    100.0    100.0    -97.000000
# 25%      100.000000    100.000000    100.0    100.0    100.000000
# 50%      100.000000    100.000000    100.0    100.0    100.000000
# 75%      100.000000    100.000000    100.0    100.0    100.000000
# max      100.000000    100.000000    100.0    100.0    100.000000
#
#              WAP006        WAP007        WAP008        WAP009        WAP010  \
# count  19937.000000  19937.000000  19937.000000  19937.000000  19937.000000
# mean      97.130461     94.733661     93.820234     94.693936     99.163766
# std       22.931890     30.541335     33.010404     30.305084     12.634045
# ...

# %%
print('Unique values of BUILDINGID', wifi_train_df.BUILDINGID.unique())
print('Unique values of FLOOR', wifi_train_df.FLOOR.unique())
print('Unique values of SPACEID', wifi_train_df.SPACEID.unique())
# Out:
# Unique values of BUILDINGID [1 0 2]
# Unique values of FLOOR [2 0 3 4 1]
# Unique values of SPACEID [106 103 102 122 105 101 112 104 110 108 109 111 107  15  29 117  16  28
#   22  10   2   4   3   5   6   9  27   8   7  26  18 216  17 217 247 248
#  246 245 244 243 242 241 240 201 202 204 203 205 207 206 209 211 208 210
#  212 214 213 215 121 219 221 222 218 220 250 223 225 224 229 226 227 228
#  233 231 230 232 236 235 234 237 238 239 141 140 143 113 114 116 115 120
#  118 128 119 129 125 124 131 127 132 126 133 134 137 135 136 253 254 123
#  130 138 139 142 146 147 249 144   1  30  25  13  12  11  14]

# %%
msk = np.random.rand(len(wifi_train_df)) < 0.8
trainDF = wifi_train_df[msk]
testDF = wifi_train_df[~msk]

print('Size of Wifi train data', trainDF.shape)
print('Size of Wifi test data', testDF.shape)
# Out:
# Size of Wifi train data (15886, 529)
# Size of Wifi test data (4051, 529)

# %%
cols = [col for col in trainDF.columns if col not in ['FLOOR','BUILDINGID',
                                                      'SPACEID', 'RELATIVEPOSITION',
                                                      'USERID','PHONEID','LATITUDE',
                                                     'LONGITUDE','TIMESTAMP']]
X = trainDF[cols]

y = trainDF['SPACEID']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7746537977339488
